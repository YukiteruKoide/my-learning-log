# %%
# %run /Users/yukiteru.koide@databricks.com/99_my-learning-log/04_Python_module/module1

# %%
# %run /Users/yukiteru.koide@databricks.com/99_my-learning-log/04_Python_module/module2

# %%
myfunc1()
myfunc2()

# %%
# %run /Users/yukiteru.koide@databricks.com/99_my-learning-log/04_Python_module/__init__
