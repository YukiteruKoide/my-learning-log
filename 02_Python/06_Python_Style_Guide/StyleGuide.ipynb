# %% [markdown]
# # Style Guide

# %% [markdown]
# ## 変数の定義

# %%
# 変数の定義
x = 1
y = 1

# wrong
x      = 1
y      = 1

# %%
# 関数の引数の「=」にはスペース不要
def complex(real, imag=0,0):
    return magic(r=real, i=imag)
  
# wrong
def complex(real, imag=0,0):
    return magic(r = real, i = imag)

# %%
# operatorの前後にスペースが必要
x = 1 + 2
x = x*2 - 1
a = x*x + y*y
c = (a+1) * (a-1)

# wrong
x = 1+2
x = x * 2 - 1
a = x * x + y * y
c = (a + 1) * (a - 1)

# %%
# カンマの後ろにはスペースを入れる
# correct
range(1, 11)
a = [1, 2, 3]

# wrong
range(1,11)
a = [1,2]

# カンマの後ろに閉じカッコがくる場合はスペース不要
# correct
foo = (0, )

# wrong
foo = (0,)

# %%
# correct
FILES = [
  'setup.fg',
  'tox.init',
]

# wrong
FILES = ['setup.fg', 'tox.init',]

# %% [markdown]
# ## 行の折り返し

# %%
# correct
foo = long_function_name(a, b, c, 
                         d, e, f)

foo = long_function_name(
  a, 
  b, 
  c, 
  d, 
  e, 
  f)

# wrong
foo = long_function_name(a, b, c,
                         d, e, f)

# \で区切って改行する
# correct
a = 100000000 \ 
    + 1000000000 \
    + 100000000

# wrong
a = 100000000 + \
    1000000000 + \
    100000000


# 関数間は2行空ける
def func():
  pass


def func2():
  pass

# %% [markdown]
# ## importの書き方

# %%
# correct
import os
import sys

# wrong
import os, sys

# 順番
# 1. Standard Library(time, sys)
# 2. Third-Party Library(numpy, pandas)
# 3. Our Library
# 4. Local Library
# それぞれ一行空ける（abc順）

# %% [markdown]
# ## コメント

# %%
# コメントは常に最新化する
# なるべく英語で書く
# 書くときは文章で書くのが望ましい
# # の後にスペースを入れる
# インラインコメントはコードの後に半角スペースを2つ入れて# 書く
# なぜそう書いたか？の方が有益

# %% [markdown]
# ## 変数、関数の命名規則

# %%
# 変数名や関数名はsnake_caseで書く
# クラス名はCamelCaseで書く
# モジュールやパッケージ名: なるべく短いlower caseで必要であればsnake caseで書く
