# %% [markdown]
# # test

# %% [markdown]
# ## assert

# %%
a = 1
b = 1
print((a + b) == 2)
assert a + b == 2, 'a + b is equal to 2!'

# %%
def power(base, exp):
  return base * exp


assert power(3, 2) == 9, '3 * 2 must be 9'
